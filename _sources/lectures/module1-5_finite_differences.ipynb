# %% [markdown]
# # 5) Finite Differences
#
# Last time:
#
# - Introduction to programming in Julia
# - Errors
# - Plotting
#
# Today:
# 1. Introduction to Finite Difference schemes

# %% [markdown]
# ## 1. Introduction to Finite Difference schemes
